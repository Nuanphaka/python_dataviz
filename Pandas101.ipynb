# %%
import pandas as pd

# %% [markdown]
# # Define path to table files

# %%
w_restaurant_PATH = 'C:\\Users\\acer\\Documents\\lek13\\w_restaurant.csv'
search_click_PATH = 'C:\\Users\\acer\\Documents\\lek13\\search_click.csv'

# %% [markdown]
# # Load files into memory  โหลดไฟล์เข้า Python

# %%
w_restaurant_df = pd.read_csv(w_restaurant_PATH)
search_click_df = pd.read_csv(search_click_PATH)

# %% [markdown]
# # load at the table

# %%
w_restaurant_df
# Out:
#             id                                  name  domain_id  closed  \
# 0            2                      นครินทร์ทันตกรรม          2       0
# 1            4                          Corner House          1       0
# 2            5                        วัดโลกยสุธาราม          4       0
# 3            6                        นันท์คาราโอเกะ          1       0
# 4            7                           Buono Caffe          1       0
# ...        ...                                   ...        ...     ...
# 246842  340068                            Sushi Tama          1       0
# 246843  340070                     สะบายดี คาราโอเกะ          1       0
# 246844  340074                      สเต็กแม่&กาแฟลูก          1       0
# 246845  340079                              Mom Made          1       0
# 246846  340091  ก๋วยเตี๋ยวหมูน้ำตก ก๋วยเตี๋ยวเรือทอง          1       0
#
#                           city_name zipcode  geohash  new_open  \
# ...

# %%
# มี data เท่ากับจำนวนrows คือ 246847 และ 32 columns

# %%
search_click_df
# Out:
#         click_timestamp                             search_id  business_id  \
# 0               11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1     298839.0
# 1               30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e     171372.0
# 2               32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224      16157.0
# 3               00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b      89741.0
# 4               23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639     189564.0
# ...                 ...                                   ...          ...
# 1048570         05:28.8  99aab616-6fc5-4fbf-994b-4aebee7bb360     278479.0
# 1048571         15:28.8  d70a2c5d-ee94-4e4c-9f7c-c5faac6db12a     321885.0
# 1048572         11:49.4  4c1de7fe-300e-41aa-9d01-914344fc3753     221035.0
# 1048573         10:33.7  2ec0ddec-e450-4b98-9779-42b77aa7eda5     220572.0
# 1048574         13:51.4  5741d9cf-b9f1-441d-aa83-d2b0179bf874     310448.0
#
#          display_position  time_diff_nanos    ads
# ...

# %%
search_click_df.tail()
# Out:
#         click_timestamp                             search_id  business_id  \
# 1048570         05:28.8  99aab616-6fc5-4fbf-994b-4aebee7bb360     278479.0
# 1048571         15:28.8  d70a2c5d-ee94-4e4c-9f7c-c5faac6db12a     321885.0
# 1048572         11:49.4  4c1de7fe-300e-41aa-9d01-914344fc3753     221035.0
# 1048573         10:33.7  2ec0ddec-e450-4b98-9779-42b77aa7eda5     220572.0
# 1048574         13:51.4  5741d9cf-b9f1-441d-aa83-d2b0179bf874     310448.0
#
#          display_position  time_diff_nanos    ads
# 1048570                 8     2.072630e+11  False
# 1048571                 8     6.931413e+10  False
# 1048572                 8     3.105162e+10  False
# 1048573                 8     7.848904e+10  False
# 1048574                 8     3.157757e+10  False

# %%
# shape ดูขนาดรูปร่างของตาราง

# %%
search_click_df.shape
# Out:
# (1048575, 6)

# %%
# ต่อไปเตรียม data

# %% [markdown]
# # data preprocessing

# %% [markdown]
# # missing

# %%
# ดูทุกค่าบนหัวตาราง ถ้ามี true คือยังีช่องว่างอยู่หรือมี missing

# %%
w_restaurant_df.isnull().any()
# Out:
# id                         False
# name                       False
# domain_id                  False
# closed                     False
# city_name                  False
# zipcode                     True
# geohash                    False
# new_open                   False
# weighted_average_rating    False
# number_of_chains            True
# number_of_bookmarks         True
# number_of_reviews          False
# number_of_product_tags     False
# total_number_of_views      False
# number_of_checkins         False
# number_of_menu_groups      False
# number_of_menu_photos      False
# category_name              False
# price_range                 True
# avg_price                   True
# parking                     True
# credit_card_accepted        True
# good_for_groups             True
# good_for_kids               True
# bookable                    True
# best_of_wongnai             True
# wifi                        True
# number_of_seats             True
# ...

# %%
# ตัด Data นั้นออก 
# เติมค่า 0, medein, mean,

# %% [markdown]
# # delete row missing value
# ####  วิธีการแก้ missing แบบที่1 ลบData ที่มี missing ออกไป

# %%
w_restaurant_df.dropna(subset=['zipcode','number_of_chains'])
# Out:
#             id          name  domain_id  closed                    city_name  \
# 61         114      มานีมีนม          1       0  Bangkok Metropolitan Region
# 114        224  สเต็กลุงหนวด          1       0  Bangkok Metropolitan Region
# 115        225      Mr.shake          1       0  Bangkok Metropolitan Region
# 131        267           KFC          1       0  Bangkok Metropolitan Region
# 140        297    Miss Mamon          1       1  Bangkok Metropolitan Region
# ...        ...           ...        ...     ...                          ...
# 246722  339787  Chang coffee          1       0                   Chiang Mai
# 246752  339864      Hokkaido          1       0  Bangkok Metropolitan Region
# 246815  340000  สเต็กลุงหนวด          1       0                 Nakhon Sawan
# 246834  340048     Kuppadeli          1       1  Bangkok Metropolitan Region
# 246842  340068    Sushi Tama          1       0  Bangkok Metropolitan Region
#
# ...

# %%
# [ ] ข้างในเป็น list :ซึ่งสามารถใส่ได้หลายฟิล เช่น ['zipcode','number_of_chains']

# %%
w_restaurant_df = w_restaurant_df.dropna(subset=['zipcode','number_of_chains'])

# %% [markdown]
# # fill defauit value to the data
# ### วิธีการแก้ missing แบบที่2

# %%
# อัพเดทพรายฟิล ชื่อตารางแล้วใส่ชื่อคอลัมน์ที่ต้องการเอาออก

# %%
w_restaurant_df['parking'].fillna(0)
# Out:
# 61        3.0
# 114       3.0
# 115       0.0
# 131       3.0
# 140       3.0
#          ...
# 246722    1.0
# 246752    3.0
# 246815    3.0
# 246834    0.0
# 246842    3.0
# Name: parking, Length: 13669, dtype: float64

# %%
w_restaurant_df['parking']= w_restaurant_df['parking'].fillna(0)
# Out:
# C:\Users\acer\Miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Select part of the table by value
# #### การตัดตารางเอาเฉพราะบางส่วน
# #### part of the table = table [data condition==True]

# %%
# เช่น อยากได้ร้านที่มีที่จอดรถมากกว่า5
# โดยใช้ค่า บูลีน

# %%
w_restaurant_df['parking']> 5
# Out:
# 61        False
# 114       False
# 115       False
# 131       False
# 140       False
#           ...
# 246722    False
# 246752    False
# 246815    False
# 246834    False
# 246842    False
# Name: parking, Length: 13669, dtype: bool

# %%
# เช่น อยากได้ร้านที่มีที่จอดรถมากกว่า3 
 โดยใช้คำสั่ง part of the tableที่ต้องการ= tableที่ต้องการ [data condition==True]
# นี่ดูแค่ฟิลเดียว

# %%
w_restaurant_df['parking']>=3
# Out:
# 61         True
# 114        True
# 115       False
# 131        True
# 140        True
#           ...
# 246722    False
# 246752     True
# 246815     True
# 246834    False
# 246842     True
# Name: parking, Length: 13669, dtype: bool

# %%
# เอาฟิลเมื่อกี้มาใส่

# %%
w_restaurant_df[w_restaurant_df['parking']>=3]
# Out:
#             id                             name  domain_id  closed  \
# 61         114                         มานีมีนม          1       0
# 114        224                     สเต็กลุงหนวด          1       0
# 131        267                              KFC          1       0
# 140        297                       Miss Mamon          1       1
# 149        344                  Inthanin Coffee          1       0
# ...        ...                              ...        ...     ...
# 246646  339670  Four Seasons Chinese Restaurant          1       0
# 246684  339718                     Jeffer Steak          1       0
# 246752  339864                         Hokkaido          1       0
# 246815  340000                     สเต็กลุงหนวด          1       0
# 246842  340068                       Sushi Tama          1       0
#
#                           city_name zipcode  geohash  new_open  \
# 61      Bangkok Metropolitan Region   10312  w4rw3e0         0
# ...

# %% [markdown]
# # HW select all restaurant from your hometown

# %%
set(w_restaurant_df['city_name'])
# Out:
# {'Amnat Charoen',
#  'Ang Thong',
#  'Bali',
#  'Bangkok Metropolitan Region',
#  'Bueng Kan',
#  'Buri Ram',
#  'Chachoengsao',
#  'Chai Nat',
#  'Chaiyaphum',
#  'Chanthaburi',
#  'Chiang Mai',
#  'Chiang Rai',
#  'Chiba-ken',
#  'Chon Buri',
#  'Chumphon',
#  'Greater Manchester',
#  'Hokkaido',
#  'Hua Hin',
#  'Kalasin',
#  'Kamphaeng Phet',
#  'Kanchanaburi',
#  'Khon Kaen',
#  'Krabi',
#  'Lampang',
#  'Lamphun',
#  'Loei',
#  'Lopburi',
#  'Maha Sarakham',
#  'Mukdahan',
#  'Nakhon Nayok',
#  'Nakhon Phanom',
#  'Nakhon Ratchasima',
#  'Nakhon Sawan',
#  'Nakhon Si Thammarat',
#  'Nan',
#  'Narathiwat',
#  'Nong Bua Lam Phu',
#  'Nong Khai',
#  'Nordrhein-Westfalen',
#  'Pattani',
#  'Perak',
#  'Phang-nga',
#  'Phatthalung',
#  'Phayao',
#  'Phetchabun',
#  'Phetchaburi',
#  'Phichit',
#  'Phitsanulok',
#  'Phra Nakhon Si Ayutthaya',
#  'Phrae',
#  'Phuket',
#  'Prachin Buri',
#  'Prachuap Khiri Khan',
#  'Ranong',
#  'Ratchaburi',
#  'Rayong',
#  'Roi Et',
#  'Sa Kaeo',
# ...

# %%
w_restaurant_df[w_restaurant_df['city_name']== 'Khon Kaen']
# Out:
#             id                               name  domain_id  closed  \
# 1776      3011                laemcharoen Seafood          1       0
# 1898      3264                                KFC          1       0
# 4712      8789   Coffee Der La (คอฟฟี่ เด้อ หล่า)          1       0
# 7493     13529                              Mrbun          1       0
# 9568     16754                      MK Restaurant          1       0
# ...        ...                                ...        ...     ...
# 239099  331178                                KFC          1       0
# 240935  333256                  วุฒิ-ศักดิ์คลินิก          2       0
# 243836  336471                      กาแฟสดชาวดอย           1       0
# 246060  339017                  Healthy breakfast          1       0
# 246312  339286  สเวนเซ่นส์ เซ็นทรัลพลาซ่า ขอนแก่น          1       0
#
#         city_name zipcode  geohash  new_open  weighted_average_rating  \
# ...

# %% [markdown]
# # save table to a file

# %%
w_restaurant_df.to_csv('test.csv')

# %% [markdown]
# # week2

# %%
import pandas as pd

# %%
w_restaurant_PATH = 'C:\\Users\\acer\\Documents\\lek13\\w_restaurant.csv'
search_click_PATH = 'C:\\Users\\acer\\Documents\\lek13\\search_click.csv'
w_restaurant_df = pd.read_csv(w_restaurant_PATH)
search_click_df = pd.read_csv(search_click_PATH)

# %%
w_restaurant_df
# Out:
#             id                                  name  domain_id  closed  \
# 0            2                      นครินทร์ทันตกรรม          2       0
# 1            4                          Corner House          1       0
# 2            5                        วัดโลกยสุธาราม          4       0
# 3            6                        นันท์คาราโอเกะ          1       0
# 4            7                           Buono Caffe          1       0
# ...        ...                                   ...        ...     ...
# 246842  340068                            Sushi Tama          1       0
# 246843  340070                     สะบายดี คาราโอเกะ          1       0
# 246844  340074                      สเต็กแม่&กาแฟลูก          1       0
# 246845  340079                              Mom Made          1       0
# 246846  340091  ก๋วยเตี๋ยวหมูน้ำตก ก๋วยเตี๋ยวเรือทอง          1       0
#
#                           city_name zipcode  geohash  new_open  \
# ...

# %% [markdown]
# # select only some columns เลือกคอลัมน์ที่ต้องการ

# %%
small_table = w_restaurant_df[['name','city_name','zipcode','weighted_average_rating']]
small_table
# Out:
#                                         name                    city_name  \
# 0                           นครินทร์ทันตกรรม              Samut Songkhram
# 1                               Corner House  Bangkok Metropolitan Region
# 2                             วัดโลกยสุธาราม     Phra Nakhon Si Ayutthaya
# 3                             นันท์คาราโอเกะ  Bangkok Metropolitan Region
# 4                                Buono Caffe  Bangkok Metropolitan Region
# ...                                      ...                          ...
# 246842                            Sushi Tama  Bangkok Metropolitan Region
# 246843                     สะบายดี คาราโอเกะ  Bangkok Metropolitan Region
# 246844                      สเต็กแม่&กาแฟลูก  Bangkok Metropolitan Region
# 246845                              Mom Made          Nakhon Si Thammarat
# 246846  ก๋วยเตี๋ยวหมูน้ำตก ก๋วยเตี๋ยวเรือทอง                  Suphan Buri
#
#        zipcode  weighted_average_rating
# ...

# %%
search_click_df.head()
# Out:
#   click_timestamp                             search_id  business_id  \
# 0         11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1     298839.0
# 1         30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e     171372.0
# 2         32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224      16157.0
# 3         00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b      89741.0
# 4         23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639     189564.0
#
#    display_position  time_diff_nanos   ads
# 0                 0     2.222400e+15  True
# 1                 0     4.608380e+14  True
# 2                 0     2.581490e+15  True
# 3                 1     1.404580e+15  True
# 4                 1     9.333590e+14  True

# %% [markdown]
# # Add column from anaother table
# ## การรวมตารางแบบที่1

# %%
w_restaurant_df['id']
# Out:
# 0              2
# 1              4
# 2              5
# 3              6
# 4              7
#            ...
# 246842    340068
# 246843    340070
# 246844    340074
# 246845    340079
# 246846    340091
# Name: id, Length: 246847, dtype: int64

# %%
# ค่าที่เราจะเอาไปในตาราง

# %%
small_table['id'] = w_restaurant_df['id']
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# เอาค่าเดียวกันคนละตารางมารวมกัน

# %%
small_table.head()
# Out:
#                name                    city_name zipcode  \
# 0  นครินทร์ทันตกรรม              Samut Songkhram   75000
# 1      Corner House  Bangkok Metropolitan Region   12150
# 2    วัดโลกยสุธาราม     Phra Nakhon Si Ayutthaya   13000
# 3    นันท์คาราโอเกะ  Bangkok Metropolitan Region   10700
# 4       Buono Caffe  Bangkok Metropolitan Region   10220
#
#    weighted_average_rating  id
# 0                 5.000000   2
# 1                 2.000000   4
# 2                 4.000000   5
# 3                 0.000000   6
# 4                 3.738462   7

# %% [markdown]
# ## .map() การเพิ่มคอลัมน์เข้าไปในตาราง

# %% [markdown]
# ### add business name to search click เพิ่มคอลัมที่ชื่อว่า business_name เข้าไปในตาราง search click

# %%
search_click_df.head()
# Out:
#   click_timestamp                             search_id  business_id  \
# 0         11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1     298839.0
# 1         30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e     171372.0
# 2         32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224      16157.0
# 3         00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b      89741.0
# 4         23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639     189564.0
#
#    display_position  time_diff_nanos   ads
# 0                 0     2.222400e+15  True
# 1                 0     4.608380e+14  True
# 2                 0     2.581490e+15  True
# 3                 1     1.404580e+15  True
# 4                 1     9.333590e+14  True

# %%
search_click_df['business_name'] = search_click_df['business_id'].map(small_table.set_index('id')['name'])

# %%
# ข้อควรระวัง คีย์ในตารางหลักจะไม่ซ้ำกัน คีย์ในตารางรองจะซ้ำกันได้ 
# เพิ่มได้ที่ละ1คอลัมน์

# %%
search_click_df.head()
# Out:
#   click_timestamp                             search_id  business_id  \
# 0         11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1     298839.0
# 1         30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e     171372.0
# 2         32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224      16157.0
# 3         00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b      89741.0
# 4         23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639     189564.0
#
#    display_position  time_diff_nanos   ads            business_name
# 0                 0     2.222400e+15  True        ปูดองอันยอง Eight
# 1                 0     4.608380e+14  True                Yoshinoya
# 2                 0     2.581490e+15  True  The Hub Cafe and Eatery
# 3                 1     1.404580e+15  True     ซั่งไห่ เสี่ยวหลงเปา
# 4                 1     9.333590e+14  True                Yoshinoya

# %% [markdown]
# # .merge()
# ## combine two table
# ## การรวมสองตาราง  จะต้องตั้งชื่อตารางใหม่ก่อน

# %% [markdown]
# ![merge](merge.png)

# %%
merge_table = search_click_df.merge(small_table,how='left',left_on = 'business_id',right_on='id')

# %%
merge_table.head()
# Out:
#   click_timestamp                             search_id  business_id  \
# 0         11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1     298839.0
# 1         30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e     171372.0
# 2         32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224      16157.0
# 3         00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b      89741.0
# 4         23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639     189564.0
#
#    display_position  time_diff_nanos   ads            business_name  \
# 0                 0     2.222400e+15  True        ปูดองอันยอง Eight
# 1                 0     4.608380e+14  True                Yoshinoya
# 2                 0     2.581490e+15  True  The Hub Cafe and Eatery
# 3                 1     1.404580e+15  True     ซั่งไห่ เสี่ยวหลงเปา
# 4                 1     9.333590e+14  True                Yoshinoya
#
#                       name                    city_name zipcode  \
# 0        ปูดองอันยอง Eight  Bangkok Metropolitan Region   10110
# ...

# %% [markdown]
# ![creating](creating.png)

# %%
# พิมพ์ตามทั้งหมด ทำความเข้าใจ

# %%
sales = [{'account':'Jones LLC','Jan':150, 'Feb':200,'Mar':140},
              {'account': 'Alpha Co', 'Jan':200,'Feb':210,'Mar':215},
              {'account': 'Blue Inc','Jan':50,'Feb':90,'Mar':95}]
df = pd.DataFrame(sales)
df

# %%
sales =  [('Jones LLC',150, 200,140),
              ('Alpha Co', 200,210,215),
              ( 'Blue Inc',50,90,95)]
labels = ['account','Jan','Feb','Mar']
df = pd.DataFrame.from_records(sales,columns=labels)
df
# Out:
#      account  Jan  Feb  Mar
# 0  Jones LLC  150  200  140
# 1   Alpha Co  200  210  215
# 2   Blue Inc   50   90   95

# %%
sales = {'account': ['Jones LLC','Alpha Co','Blue Inc'],
                'Jan':[150,200,50],
                'Feb':[200,210,90],
                'Mar':[140,215,95]}
df = pd.DataFrame.from_dict(sales)
df
# Out:
#      account  Jan  Feb  Mar
# 0  Jones LLC  150  200  140
# 1   Alpha Co  200  210  215
# 2   Blue Inc   50   90   95

# %%
sales = [  ( 'account' , [ 'Jones LLC' , 'Alpha Co' , 'Blue Inc' ]),
                ('Jan' , [150,200,50]),
                ('Feb ', [200,210,90]),
                ('Mar', [140,215,95]) ]
df = pd.DataFrame.from_items(sales)
df
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   """
#      account  Jan  Feb   Mar
# 0  Jones LLC  150   200  140
# 1   Alpha Co  200   210  215
# 2   Blue Inc   50    90   95

# %%
w_restaurant_PATH = 'C:\\Users\\acer\\Documents\\lek13\\w_restaurant.csv'
search_click_PATH = 'C:\\Users\\acer\\Documents\\lek13\\search_click.csv'
w_restaurant_df = pd.read_csv(w_restaurant_PATH)
search_click_df = pd.read_csv(search_click_PATH)

# %%
w_restaurant_df.head()
# Out:
#    id              name  domain_id  closed                    city_name  \
# 0   2  นครินทร์ทันตกรรม          2       0              Samut Songkhram
# 1   4      Corner House          1       0  Bangkok Metropolitan Region
# 2   5    วัดโลกยสุธาราม          4       0     Phra Nakhon Si Ayutthaya
# 3   6    นันท์คาราโอเกะ          1       0  Bangkok Metropolitan Region
# 4   7       Buono Caffe          1       0  Bangkok Metropolitan Region
#
#   zipcode  geohash  new_open  weighted_average_rating  number_of_chains  ...  \
# 0   75000  w4rh7g3         0                 5.000000               NaN  ...
# 1   12150  w4rx73h         0                 2.000000               NaN  ...
# 2   13000  w4x98jk         0                 4.000000               NaN  ...
# 3   10700  w4rqw9q         0                 0.000000               NaN  ...
# 4   10220  w4rx4gd         0                 3.738462               NaN  ...
#
#    good_for_groups  good_for_kids  bookable  best_of_wongnai  wifi  \
# ...

# %% [markdown]
# # เริ่มนับที่แถว 0

# %%
w_restaurant_df.iloc[2,4]
# Out:
# 'Phra Nakhon Si Ayutthaya'

# %% [markdown]
# ## creat a new column which a concatanation of name,city_name,zipcode -> name(city_name(zipcode)) สร้างคอลัมน์ใหม่

# %%
'kku'
# Out:
# 'kku'

# %%
f'kku'
# Out:
# 'kku'

# %%
f'kku{w_restaurant_df.iloc[2,1]}'
# Out:
# 'kkuวัดโลกยสุธาราม'

# %% [markdown]
# # range

# %%
a= range(9)
for i in a:
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
new_column = list()

# %%
new_string = f'{w_restaurant_df.iloc[2,1]}({w_restaurant_df.iloc[2,4]}({w_restaurant_df.iloc[2,5]}))'
new_string
# Out:
# 'วัดโลกยสุธาราม(Phra Nakhon Si Ayutthaya(13000))'

# %% [markdown]
# ### วนลูป for i in range()

# %%
w_restaurant_df.shape
# Out:
# (246847, 32)

# %%
for i in range(w_restaurant_df.shape[0]):
    new_tring = f'{w_restaurant_df.iloc[i,1]}({w_restaurant_df.iloc[i,4]}({w_restaurant_df.iloc[i,5]}))'
    new_column.append(new_string)

# %%
new_column[:5]
# Out:
# ['วัดโลกยสุธาราม(Phra Nakhon Si Ayutthaya(13000))',
#  'วัดโลกยสุธาราม(Phra Nakhon Si Ayutthaya(13000))',
#  'วัดโลกยสุธาราม(Phra Nakhon Si Ayutthaya(13000))',
#  'วัดโลกยสุธาราม(Phra Nakhon Si Ayutthaya(13000))',
#  'วัดโลกยสุธาราม(Phra Nakhon Si Ayutthaya(13000))']

# %%
w_restaurant_df['new_string']=new_column

# %%
w_restaurant_df.head()
# Out:
#    id              name  domain_id  closed                    city_name  \
# 0   2  นครินทร์ทันตกรรม          2       0              Samut Songkhram
# 1   4      Corner House          1       0  Bangkok Metropolitan Region
# 2   5    วัดโลกยสุธาราม          4       0     Phra Nakhon Si Ayutthaya
# 3   6    นันท์คาราโอเกะ          1       0  Bangkok Metropolitan Region
# 4   7       Buono Caffe          1       0  Bangkok Metropolitan Region
#
#   zipcode  geohash  new_open  weighted_average_rating  number_of_chains  ...  \
# 0   75000  w4rh7g3         0                 5.000000               NaN  ...
# 1   12150  w4rx73h         0                 2.000000               NaN  ...
# 2   13000  w4x98jk         0                 4.000000               NaN  ...
# 3   10700  w4rqw9q         0                 0.000000               NaN  ...
# 4   10220  w4rx4gd         0                 3.738462               NaN  ...
#
#    good_for_kids  bookable  best_of_wongnai  wifi  number_of_seats  \
# ...
