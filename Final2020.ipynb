# %%
import pandas as pd

# %%
covid= 'C:\\lek\\.ipynb_checkpoints\\Covid_19.csv'

# %%
covid_df = pd.read_csv(covid)
covid_df
# Out:
#        Sno                 Date   Province/State Country          Last Update  \
# 0        1  01/22/2020 12:00:00            Anhui   China  01/22/2020 12:00:00
# 1        2  01/22/2020 12:00:00          Beijing   China  01/22/2020 12:00:00
# 2        3  01/22/2020 12:00:00        Chongqing   China  01/22/2020 12:00:00
# 3        4  01/22/2020 12:00:00           Fujian   China  01/22/2020 12:00:00
# 4        5  01/22/2020 12:00:00            Gansu   China  01/22/2020 12:00:00
# ...    ...                  ...              ...     ...                  ...
# 1714  1715  02/17/2020 22:00:00      Madison, WI      US  2020-02-05T21:53:02
# 1715  1716  02/17/2020 22:00:00       Orange, CA      US  2020-02-01T19:53:03
# 1716  1717  02/17/2020 22:00:00  San Antonio, TX      US  2020-02-13T18:53:02
# 1717  1718  02/17/2020 22:00:00      Seattle, WA      US  2020-02-09T07:03:04
# 1718  1719  02/17/2020 22:00:00        Tempe, AZ      US  2020-02-01T19:43:03
#
# ...

# %%
covid_df.head()
# Out:
#    Sno                 Date Province/State Country          Last Update  \
# 0    1  01/22/2020 12:00:00          Anhui   China  01/22/2020 12:00:00
# 1    2  01/22/2020 12:00:00        Beijing   China  01/22/2020 12:00:00
# 2    3  01/22/2020 12:00:00      Chongqing   China  01/22/2020 12:00:00
# 3    4  01/22/2020 12:00:00         Fujian   China  01/22/2020 12:00:00
# 4    5  01/22/2020 12:00:00          Gansu   China  01/22/2020 12:00:00
#
#    Confirmed  Deaths  Recovered
# 0          1       0          0
# 1         14       0          0
# 2          6       0          0
# 3          1       0          0
# 4          0       0          0

# %%
covid_df.shape
# Out:
# (1719, 8)

# %%
covid_df.isnull().any()
# Out:
# Sno               False
# Date              False
# Province/State     True
# Country           False
# Last Update       False
# Confirmed         False
# Deaths            False
# Recovered         False
# dtype: bool

# %%
covid_df['Province/State'].fillna('Unkown',inplace=True)

# %%
covid_df.head()
# Out:
#    Sno                 Date Province/State Country          Last Update  \
# 0    1  01/22/2020 12:00:00          Anhui   China  01/22/2020 12:00:00
# 1    2  01/22/2020 12:00:00        Beijing   China  01/22/2020 12:00:00
# 2    3  01/22/2020 12:00:00      Chongqing   China  01/22/2020 12:00:00
# 3    4  01/22/2020 12:00:00         Fujian   China  01/22/2020 12:00:00
# 4    5  01/22/2020 12:00:00          Gansu   China  01/22/2020 12:00:00
#
#    Confirmed  Deaths  Recovered
# 0          1       0          0
# 1         14       0          0
# 2          6       0          0
# 3          1       0          0
# 4          0       0          0

# %%
covid_df.isnull().any()
# Out:
# Sno               False
# Date              False
# Province/State    False
# Country           False
# Last Update       False
# Confirmed         False
# Deaths            False
# Recovered         False
# dtype: bool

# %%
covid_1= covid_df[['Country','Province/State','Confirmed','Deaths','Recovered']]
covid_1.head()
# Out:
#   Country Province/State  Confirmed  Deaths  Recovered
# 0   China          Anhui          1       0          0
# 1   China        Beijing         14       0          0
# 2   China      Chongqing          6       0          0
# 3   China         Fujian          1       0          0
# 4   China          Gansu          0       0          0

# %%
covid_1.isnull().any()
# Out:
# Country           False
# Province/State    False
# Confirmed         False
# Deaths            False
# Recovered         False
# dtype: bool

# %%
covid_g=covid_1.groupby(['Country','Province/State']).mean().reset_index()

# %%
covid_g
# Out:
#                   Country   Province/State  Confirmed  Deaths  Recovered
# 0               Australia  New South Wales   4.000000     0.0   2.181818
# 1               Australia       Queensland   3.900000     0.0   0.000000
# 2               Australia  South Australia   2.000000     0.0   0.117647
# 3               Australia           Unkown   2.666667     0.0   0.000000
# 4               Australia         Victoria   3.454545     0.0   0.909091
# ..                    ...              ...        ...     ...        ...
# 116                    US      Seattle, WA   1.000000     0.0   0.529412
# 117                    US        Tempe, AZ   1.000000     0.0   0.000000
# 118                    US       Washington   1.000000     0.0   0.000000
# 119  United Arab Emirates           Unkown   6.300000     0.0   0.750000
# 120               Vietnam           Unkown   8.653846     0.0   2.192308
#
# [121 rows x 5 columns]

# %%
covid_1.to_csv('Covid19.csv')

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
covid_2= covid_1.iloc[:8,:] 
covid_2
# Out:
#   Country Province/State  Confirmed  Deaths  Recovered
# 0   China          Anhui          1       0          0
# 1   China        Beijing         14       0          0
# 2   China      Chongqing          6       0          0
# 3   China         Fujian          1       0          0
# 4   China          Gansu          0       0          0
# 5   China      Guangdong         26       0          0
# 6   China        Guangxi          2       0          0
# 7   China        Guizhou          1       0          0

# %%
plt.bar([1,2,3,4,5,6,7,8],covid_2.iloc[:,2])      #เลือกทุกแถว เลือกคอลัมน์ที่2
plt.title(u'โควิด19',fontname='Tahoma',fontsize='18')     #ตั้งชื่อกราฟ
plt.xlabel('Province/State')
plt.ylabel('Confirmed')
# Out:
# Text(0, 0.5, 'Confirmed')

# %%
covid_np= covid_2.iloc[:50,:-1].to_numpy()
covid_np[:8,:]
# Out:
# array([['China', 'Anhui', 1, 0],
#        ['China', 'Beijing', 14, 0],
#        ['China', 'Chongqing', 6, 0],
#        ['China', 'Fujian', 1, 0],
#        ['China', 'Gansu', 0, 0],
#        ['China', 'Guangdong', 26, 0],
#        ['China', 'Guangxi', 2, 0],
#        ['China', 'Guizhou', 1, 0]], dtype=object)

# %%
plt.scatter(covid_np[:,1],covid_np[:,2])

# %% [markdown]
# # ดึงตารางเข้าสู่ power BI

# %%
import pandas as pd
covid=pd.read_csv('C:\\lek\\.ipynb_checkpoints\\Covid19.csv')

# %%
covid
# Out:
#       Unnamed: 0 Country   Province/State  Confirmed  Deaths  Recovered
# 0              0   China            Anhui          1       0          0
# 1              1   China          Beijing         14       0          0
# 2              2   China        Chongqing          6       0          0
# 3              3   China           Fujian          1       0          0
# 4              4   China            Gansu          0       0          0
# ...          ...     ...              ...        ...     ...        ...
# 1714        1714      US      Madison, WI          1       0          0
# 1715        1715      US       Orange, CA          1       0          0
# 1716        1716      US  San Antonio, TX          1       0          0
# 1717        1717      US      Seattle, WA          1       0          1
# 1718        1718      US        Tempe, AZ          1       0          0
#
# [1719 rows x 6 columns]

# %% [markdown]
# ![oo0](101.png)

# %% [markdown]
# ![jyyh](202.png)

# %% [markdown]
# ![yhggft](303.png)

# %% [markdown]
# ![bgs](404.png)
